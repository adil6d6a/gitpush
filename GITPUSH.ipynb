# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ============================= FORM ============================= #
# @markdown #### ⬅️ Archive Files
MODE = "ZIP" #@param ["ZIP", "TAR", "7Z"]
FILENAME = "/content/drive/MyDrive/anwa/Leo4k.zip"  # @param {type:"string"}
PATH_TO_FILE = "/content/drive/MyDrive/Leo (2023) TRUE WEB-DL - 4K SDR - 2160p - HEVC - UNTOUCHED - (DD+5.1 ATMOS - 768Kbps & AAC 2.0) [Tamil + Telugu + Hindi + Malayalam + Kannada]  - 18GB - Soft ESub.mkv"  # @param {type:"string"}
ARCHIVE_PASSWORD = "lolan1234" #@param {type:"string"}

# option supports b k m g (bytes, kilobytes, megabytes, gigabytes)
SPLIT_MB = 100 #@param [25,100,1024, 2000, 3072, 4000, 5120, 0] {type:"raw"}
SPLIT = f"{SPLIT_MB}m" if SPLIT_MB > 0 else "no"

compress = 4#@param  {type:"slider", min:0, max:9, step:0}
#@markdown <font size=2%>Use this to path separate between to this character `|`. Ex `path/to /1 | path/to/2` </br>#Split only in zip mode.(Only for noobs)
# ================================================================ #
from pathlib import PurePosixPath

pathList = PATH_TO_FILE.split('|')
if MODE == "ZIP":
    if not FILENAME:
      FILENAME = "/content/NEW_FILE.ZIP"
    if ARCHIVE_PASSWORD:
      passADD = f'--password "{ARCHIVE_PASSWORD}"'
    else:
      passADD = ''
    splitC = f"-s {SPLIT}" if not 'no' in SPLIT else ""
    for part in pathList:
      pathdic = PurePosixPath(part.strip())
      parent = pathdic.parent
      partName = pathdic.parts[-1]
      cmd = f'cd "{parent}" && zip {passADD} -{compress} {splitC} -v -r -u "{FILENAME}" "{partName}"'
      # !$cmd
elif MODE == "TAR":
    if not FILENAME:
      FILENAME = "/content/NEW_FILE"
    cmd = f'GZIP=-{compress} tar -zcvf "{FILENAME}.tar.gz" {PATH_TO_FILE}'
    # !$cmd
else:
    if not FILENAME:
        FILENAME = "/content/NEW_FILE"
    for part in pathList:
      pathdic = PurePosixPath(part.strip())
      parent = pathdic.parent
      partName = pathdic.parts[-1]
      cmd = f'cd "{parent}" && 7z a -mx={compress} "{FILENAME}.7z" "{partName}"'
      # !$cmd

# %%
# %cd /content/drive/MyDrive/anwa/
# Out:
# /content/drive/MyDrive/anwa

# %%
# %cd /content/drive/MyDrive/anwa/Kaabil/
# Out:
# /content/drive/MyDrive/anwa/Kaabil

# %%
rm -f ./.git/index.lock

# %%
# !git config --global user.email "sptheeran@gmail.com"
# !git config --global user.name "theeran"

# %%
# !git clone https://adils12103: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@github.com/adils12103/Kaabil.git
# Out:
# Cloning into 'Kaabil'...
# ...

# %%
  # !git add Kaabil.zip
  # !git commit -m "added file"
  # !git push https://adils12103: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@github.com/adils12103/Kaabil.git
# Out:
# [main (root-commit) e081212] added file
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 Kaabil.zip
# Enumerating objects: 3, done.
# Counting objects: 100% (3/3), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 97.88 MiB | 22.25 MiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# remote: warning: See https://gh.io/lfs for more information.
# remote: warning: File Kaabil.zip is 97.85 MB; this is larger than GitHub's recommended maximum file size of 50.00 MB
# remote: warning: GH001: Large files detected. You may want to try Git Large File Storage - https://git-lfs.github.com.
# To https://github.com/adils12103/Kaabil.git
#  * [new branch]      main -> main

# %%
temp = "Kaabil.z0"
for i in range(1,10):
  file_name=f"{temp}{i}"
  # !git add {file_name}
  # !git commit -m "added file"
  # !git push https://adils12103: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@github.com/adils12103/Kaabil.git
# Out:
# [main b8ab114] added file
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 Kaabil.z05
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 100.03 MiB | 17.74 MiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# remote: warning: See https://gh.io/lfs for more information.
# remote: warning: File Kaabil.z05 is 100.00 MB; this is larger than GitHub's recommended maximum file size of 50.00 MB
# remote: warning: GH001: Large files detected. You may want to try Git Large File Storage - https://git-lfs.github.com.
# To https://github.com/adils12103/Kaabil.git
#    d3ee244..b8ab114  main -> main
# [main 72e5695] added file
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 Kaabil.z06
# Enumerating objects: 4, done.
# ...

# %%
temp = "Kaabil.z"
for i in range(10,74):
    file_name = f"{temp}{i}"
    print(f"Processing file: {file_name}")
    # !git add {file_name}
    # !git commit -m "added new file"
    # !git push https://adils12103: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@github.com/adils12103/Kaabil.git
# Out:
# Processing file: Kaabil.z10
# [main f307978] added new file
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 Kaabil.z10
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 100.03 MiB | 20.71 MiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# remote: warning: See https://gh.io/lfs for more information.
# remote: warning: File Kaabil.z10 is 100.00 MB; this is larger than GitHub's recommended maximum file size of 50.00 MB
# remote: warning: GH001: Large files detected. You may want to try Git Large File Storage - https://git-lfs.github.com.
# To https://github.com/adils12103/Kaabil.git
#    5661c4d..f307978  main -> main
# Processing file: Kaabil.z11
# [main c49c045] added new file
#  1 file changed, 0 insertions(+), 0 deletions(-)
# ...

# %%
# !git push https://adils12103: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@github.com/adils12103/Kaabilfork.git
# Out:
# fatal: not a git repository (or any of the parent directories): .git
